# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("ASGN2/IMDB Dataset.csv")
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df['sentiment']=df['sentiment'].astype("string")
df['sentiment'] = df['sentiment'].map({'positive': 1, 'negative': 0})

# %%
df['review']=df['review'].astype(str)
df.dtypes
# Out:
# review       object
# sentiment     int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df['review'],df['sentiment'],test_size=0.2)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D,Flatten

# %%
# Build model

tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train)
input_dim = len(tokenizer.word_index) + 1
# Convert text to sequences
x_train = tokenizer.texts_to_sequences(x_train)
x_test = tokenizer.texts_to_sequences(x_test)
x_train = pad_sequences(x_train, maxlen=200)
x_test = pad_sequences(x_test, maxlen=200)
y_train = np.array(y_train)
y_test = np.array(y_test)


model = Sequential()
model.add(Embedding(input_dim=input_dim, output_dim=128, input_length=200))
model.add(Flatten())  # Makes shape (batch_size, 200 * 128)
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train and evaluate
model.fit(x_train, y_train, epochs=2)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1250/1250 [==============================] - 191s 153ms/step - loss: 0.3444 - accuracy: 0.8404
# Epoch 2/5
# 1250/1250 [==============================] - 193s 154ms/step - loss: 0.0376 - accuracy: 0.9878
# Epoch 3/5
# 1250/1250 [==============================] - 196s 156ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 4/5
# 1250/1250 [==============================] - 204s 163ms/step - loss: 0.0083 - accuracy: 0.9972
# Epoch 5/5
# 1250/1250 [==============================] - 199s 159ms/step - loss: 0.0128 - accuracy: 0.9956
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6946 - accuracy: 0.8542
# [0.6945613622665405, 0.854200005531311]
